# %%
from utils import *
from matplotlib import pyplot as plt

# %%
img = np.ones((400, 400, 3), np.uint8)*255

# %%
cv.line(img, (30, 30), (100, 100), (250, 162, 193), 5)
showImage(img)

# %%
cv.rectangle(img, (230,230), (200, 200), (250, 162, 193), 5)
showImage(img)

# %%
cv.ellipse(img, (200, 30), (20, 20), 0, 0, 360, (250, 162, 193), 5)
cv.ellipse(img, (200, 30), (20, 40), 100, 0, 360, (250, 162, 193), 5)
cv.ellipse(img, (200, 30), (20, 40), 0, 0, 360, (250, 162, 193), 5)
showImage(img)

# %%
cv.circle(img,(30,60), 20, (250, 162, 193), 5)
showImage(img)

# %%
pts = np.array([[10,105],[20,130],[70,120],[50,110]], np.int32)
pts = pts.reshape((-1,1,2))
pts
# Out:
# array([[[ 10, 105]],
#
#        [[ 20, 130]],
#
#        [[ 70, 120]],
#
#        [[ 50, 110]]])

# %%
cv.polylines(img,[pts],True,(250, 162, 193), 5)
showImage(img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img,'test',(10,300), font, 1,(250, 162, 193),2,cv.LINE_AA)
showImage(img)

# %%
saveImage('./output/paint_354387.jpg', img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 saveImage('./output/paint_354387.jpg', img)
#
# File f:\code\python\cv_study\utils.py:44, in saveImage(image, url, cvt)
#      43 def saveImage(image:np.array, url:str, cvt=True):
# ---> 44     dir = os.path.dirname(url)
#      45     if not os.path.isdir(dir):
#      46         os.makedirs(dir)
#
# File c:\Users\25335\anaconda3\envs\cv\lib\ntpath.py:223, in dirname(p)
#     221 def dirname(p):
#     222     """Returns the directory component of a pathname"""
# --> 223     return split(p)[0]
#
# File c:\Users\25335\anaconda3\envs\cv\lib\ntpath.py:185, in split(p)
#     180 def split(p):
#     181     """Split a pathname.
#     182
#     183     Return tuple (head, tail) where tail is everything after the final slash.
#     184     Either part may be empty."""
# --> 185     p = os.fspath(p)
#     186     seps = _get_bothseps(p)
#     187     d, p = splitdrive(p)
#
# TypeError: expected str, bytes or os.PathLike object, not numpy.ndarray
