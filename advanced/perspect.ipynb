# %%
from utils import *
from CaptureUtils import CaptureUtils

# %%
img = readImage("../input/perspect_test.png")
showImage(img)

# %%
origin_img = readImage("../input/opencv.png")
origin_img.shape
# Out:
# (461, 372, 3)

# %%
cap = CaptureUtils(
    img=img,
    mode=2,
    color=(255, 255, 0)
)
points = cap()
points

# %%
src_point = np.array(points).astype(np.float32)
src_point
# Out:
# array([[ 117.,  192.],
#        [ 581.,  143.],
#        [ 826.,  815.],
#        [ 426., 1039.]], dtype=float32)

# %%
# src_point = [(115, 190), (579, 144), (825, 815), (426, 1041)]
dst_point = np.array([
    [0,0],
    [0, 372],
    [461, 372],
    [461, 0]
]).astype(np.float32)
M = cv.getPerspectiveTransform(src_point, dst_point[:,::-1])
M
# Out:
# array([[ 6.00268303e-01, -2.18988082e-01, -2.81856797e+01],
#        [ 5.42249275e-02,  5.13476865e-01, -1.04931875e+02],
#        [-4.20484051e-04,  1.52924425e-04,  1.00000000e+00]])

# %%
origin_img.shape[:2]
# Out:
# (461, 372)

# %%
dst = cv.warpPerspective(img, M, origin_img.shape[:2][::-1])
showImage(dst)

# %%
showImage(origin_img)
