# %%
from utils import *

# %%
img = readImage('./input/opencv.png')
showImage(img)

# %%
orb = cv.ORB_create()
orb
# Out:
# < cv2.ORB 0000021728139D10>

# %%
kp = orb.detect(img)
type(kp), len(kp)
# Out:
# (tuple, 437)

# %%
dest = cv.drawKeypoints(img, kp, (255, 255,  0))
showImage(dest)
